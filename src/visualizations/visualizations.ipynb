# %%
from main import S21MnistOperations

# %%
operator = S21MnistOperations(
    images_path='../../datasets/data/visualizations/train-images-idx3-ubyte.gz',
    labels_path='../../datasets/data/visualizations/train-labels-idx1-ubyte.gz',
)

X_train, y_train = operator.load_dataset()
print(X_train.shape)  
print(y_train.shape)

# %%
X_pca_2d        = operator.transform_pca()
X_svd_2d        = operator.transform_svd()
X_rand_svd_2d   = operator.transform_random_svd()
X_tsne_2d       = operator.transform_tsne()
X_umap_2d       = operator.transform_umap()
X_lle_2d        = operator.transform_lle()
