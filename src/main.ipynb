# %%
from helpers.matrix import S21UserBookMatrixBuilder

# %%
train_ratio, val_ratio, test_ratio = ratios = (0.7, 0.15, 0.15)

builder = S21UserBookMatrixBuilder('../datasets/data/Ratings.csv')
split = builder.build_split(ratios, 42)

X_train = split.train
X_val   = split.val
X_test  = split.test
